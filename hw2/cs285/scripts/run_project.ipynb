# %% [markdown]
# ##Setup
#
# You will need to make a copy of this notebook in your Google Drive before you can edit the homework files. You can do so with **File &rarr; Save a copy in Drive**.

# %%
#@title mount your Google Drive
#@markdown Your work will be stored in a folder called `cs285_f2022` by default to prevent Colab instance timeouts from deleting your edits.

import os
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#@title set up mount symlink

DRIVE_PATH = '/content/gdrive/My\ Drive/CS285\ Project/'
DRIVE_PYTHON_PATH = DRIVE_PATH.replace('\\', '')
if not os.path.exists(DRIVE_PYTHON_PATH):
  # %mkdir $DRIVE_PATH

## the space in `My Drive` causes some issues,
## make a symlink to avoid this
SYM_PATH = '/content/cs285_f2022'
if not os.path.exists(SYM_PATH):
  # !ln -s $DRIVE_PATH $SYM_PATH

# %%
#@title apt install requirements

#@markdown Run each section with Shift+Enter

#@markdown Double-click on section headers to show code.

# !apt update 
# !apt install -y --no-install-recommends \
        build-essential \
        curl \
        git \
        gnupg2 \
        make \
        cmake \
        ffmpeg \
        swig \
        libz-dev \
        unzip \
        zlib1g-dev \
        libglfw3 \
        libglfw3-dev \
        libxrandr2 \
        libxinerama-dev \
        libxi6 \
        libxcursor-dev \
        libgl1-mesa-dev \
        libgl1-mesa-glx \
        libglew-dev \
        libosmesa6-dev \
        lsb-release \
        ack-grep \
        patchelf \
        wget \
        xpra \
        xserver-xorg-dev \
        xvfb \
        python-opengl \
        ffmpeg
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:6 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:7 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:11 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [3,035 kB]
# Hit:12 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:13 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Get:14 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,554 kB]
# Hit:15 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:16 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [2,165 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [3,467 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,332 kB]
# Get:19 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [1,109 kB]
# Fetched 13.9 MB in 4s (3,870 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 28 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'zlib1g-dev' instead of 'libz-dev'
# build-essential is already the newest version (12.4ubuntu1).
# libxi6 is already the newest version (2:1.7.9-1).
# libxi6 set to manually installed.
# libxrandr2 is already the newest version (2:1.5.1-1).
# libxrandr2 set to manually installed.
# lsb-release is already the newest version (9.20170808ubuntu1).
# lsb-release set to manually installed.
# make is already the newest version (4.1-9.1ubuntu1).
# make set to manually installed.
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.2).
# curl is already the newest version (7.58.0-2ubuntu3.20).
# git is already the newest version (1:2.17.1-1ubuntu0.13).
# libgl1-mesa-dev is already the newest version (20.0.8-0ubuntu1~18.04.1).
# libgl1-mesa-dev set to manually installed.
# unzip is already the newest version (6.0-21ubuntu1.2).
# wget is already the newest version (1.19.4-1ubuntu2.2).
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-0ubuntu2.2).
# zlib1g-dev set to manually installed.
# ffmpeg is already the newest version (7:3.4.11-0ubuntu0.1).
# gnupg2 is already the newest version (2.2.4-1ubuntu1.6).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   ack freeglut3 libcapnp-0.6.1 libfile-next-perl libfontenc-dev libglew2.0
#   libgtk2.0-0 libgtk2.0-common libmirclient-dev libmirclient9 libmircommon-dev
#   libmircommon7 libmircookie-dev libmircookie2 libmircore-dev libmircore1
#   libmirprotobuf3 libosmesa6 libpciaccess-dev libpixman-1-dev libprotobuf-dev
#   libprotobuf-lite10 libxfont-dev libxkbcommon-dev libxkbfile-dev
#   mir-client-platform-mesa-dev python-cairo python-gi python-gi-cairo
#   python-gobject-2 python-gtk2 python-rencode swig3.0 x11-xserver-utils
#   x11proto-dri2-dev x11proto-fonts-dev x11proto-gl-dev x11proto-input-dev
#   x11proto-randr-dev x11proto-render-dev x11proto-resource-dev
#   x11proto-xf86bigfont-dev x11proto-xinerama-dev xserver-xorg-core
#   xserver-xorg-input-void xserver-xorg-video-dummy
# Suggested packages:
#   glew-utils libegl1-mesa | libegl1-x11 libvulkan1 gvfs python-gobject-2-dbg
#   python-gtk2-doc libgle3 swig-doc swig-examples swig3.0-examples swig3.0-doc
#   nickle cairo-5c xorg-docs-core openssh-server python-pyopencl
#   gstreamer1.0-plugins-base gstreamer1.0-plugins-good
#   | gstreamer1.0-plugins-ugly | gstreamer1.0-plugins-bad python-gst-1.0
#   pulseaudio pulseaudio-utils python-avahi python-netifaces cups-filters
#   cups-common cups-pdf python-cups python-opencv v4l2loopback-dkms python-yaml
#   xfonts-100dpi | xfonts-75dpi xfonts-scalable
# Recommended packages:
#   libvulkan-dev libxrandr-dev libgail-common libgtk2.0-bin ssh-askpass
#   python-lz4 python-lzo python-pil | python-imaging python-gtkglext1
#   python-dbus
# The following packages will be REMOVED:
#   xserver-xorg-core-hwe-18.04
# The following NEW packages will be installed:
#   ack ack-grep freeglut3 libcapnp-0.6.1 libfile-next-perl libfontenc-dev
#   libgl1-mesa-glx libglew-dev libglew2.0 libglfw3 libglfw3-dev libgtk2.0-0
#   libgtk2.0-common libmirclient-dev libmirclient9 libmircommon-dev
#   libmircommon7 libmircookie-dev libmircookie2 libmircore-dev libmircore1
#   libmirprotobuf3 libosmesa6 libosmesa6-dev libpciaccess-dev libpixman-1-dev
#   libprotobuf-dev libprotobuf-lite10 libxcursor-dev libxfont-dev
#   libxinerama-dev libxkbcommon-dev libxkbfile-dev mir-client-platform-mesa-dev
#   patchelf python-cairo python-gi python-gi-cairo python-gobject-2 python-gtk2
#   python-opengl python-rencode swig swig3.0 x11-xserver-utils
#   x11proto-dri2-dev x11proto-fonts-dev x11proto-gl-dev x11proto-input-dev
#   x11proto-randr-dev x11proto-render-dev x11proto-resource-dev
#   x11proto-xf86bigfont-dev x11proto-xinerama-dev xpra xserver-xorg-core
#   xserver-xorg-dev xserver-xorg-input-void xserver-xorg-video-dummy xvfb
# 0 upgraded, 60 newly installed, 1 to remove and 28 not upgraded.
# Need to get 15.0 MB of archives.
# After this operation, 65.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 xserver-xorg-core amd64 2:1.19.6-1ubuntu4.11 [1,351 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libfile-next-perl all 1.16-2 [16.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 ack all 2.22-1 [62.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/universe amd64 ack-grep all 2.22-1 [5,268 B]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgl1-mesa-glx amd64 20.0.8-0ubuntu1~18.04.1 [5,532 B]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/universe amd64 freeglut3 amd64 2.8.1-3 [73.6 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcapnp-0.6.1 amd64 0.6.1-1ubuntu1 [658 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfontenc-dev amd64 1:1.1.3-1 [13.8 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libglew2.0 amd64 2.0.0-5 [140 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libglew-dev amd64 2.0.0-5 [120 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libglfw3 amd64 3.2.1-1 [49.2 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libglfw3-dev amd64 3.2.1-1 [30.9 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-common all 2.24.32-1ubuntu1 [125 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-0 amd64 2.24.32-1ubuntu1 [1,769 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircore1 amd64 0.31.1-0ubuntu1 [26.5 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircommon7 amd64 0.31.1-0ubuntu1 [73.9 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/main amd64 libprotobuf-lite10 amd64 3.0.0-9.1ubuntu1 [97.7 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmirprotobuf3 amd64 0.31.1-0ubuntu1 [127 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmirclient9 amd64 0.31.1-0ubuntu1 [199 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircore-dev amd64 0.31.1-0ubuntu1 [21.7 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/main amd64 libprotobuf-dev amd64 3.0.0-9.1ubuntu1 [959 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxkbcommon-dev amd64 0.8.2-1~ubuntu18.04.1 [150 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircommon-dev amd64 0.31.1-0ubuntu1 [13.9 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircookie2 amd64 0.31.1-0ubuntu1 [19.7 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircookie-dev amd64 0.31.1-0ubuntu1 [4,392 B]
# Get:26 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmirclient-dev amd64 0.31.1-0ubuntu1 [47.8 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpixman-1-dev amd64 0.34.0-2 [244 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcursor-dev amd64 1:1.1.15-1 [26.5 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-fonts-dev all 2018.4-4 [2,620 B]
# Get:30 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxfont-dev amd64 1:2.0.3-1 [118 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-xinerama-dev all 2018.4-4 [2,628 B]
# Get:32 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxinerama-dev amd64 2:1.1.3-1 [8,404 B]
# Get:33 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxkbfile-dev amd64 1:1.0.9-2 [74.3 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic/main amd64 mir-client-platform-mesa-dev amd64 0.31.1-0ubuntu1 [11.0 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic/universe amd64 patchelf amd64 0.9-1 [46.5 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-cairo amd64 1.16.2-1 [56.4 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python-gi amd64 3.26.1-2ubuntu1 [197 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 python-gi-cairo amd64 3.26.1-2ubuntu1 [6,632 B]
# Get:39 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-gobject-2 amd64 2.28.6-12ubuntu3 [180 kB]
# Get:40 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-gtk2 amd64 2.24.0-5.1ubuntu2 [619 kB]
# Get:41 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-opengl all 3.1.0+dfsg-1 [496 kB]
# Get:42 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-rencode amd64 1.0.5-1build2 [37.4 kB]
# Get:43 http://archive.ubuntu.com/ubuntu bionic/universe amd64 swig3.0 amd64 3.0.12-1 [1,094 kB]
# Get:44 http://archive.ubuntu.com/ubuntu bionic/universe amd64 swig amd64 3.0.12-1 [6,460 B]
# Get:45 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11-xserver-utils amd64 7.7+7build1 [159 kB]
# Get:46 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-dri2-dev all 2018.4-4 [2,620 B]
# Get:47 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-gl-dev all 2018.4-4 [2,612 B]
# Get:48 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-input-dev all 2018.4-4 [2,620 B]
# Get:49 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-randr-dev all 2018.4-4 [2,620 B]
# Get:50 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-render-dev all 2:2018.4-4 [2,620 B]
# Get:51 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-resource-dev all 2018.4-4 [2,620 B]
# Get:52 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-xf86bigfont-dev all 2018.4-4 [2,628 B]
# Get:53 http://archive.ubuntu.com/ubuntu bionic/universe amd64 xserver-xorg-input-void amd64 1:1.4.1-1build3 [6,806 B]
# Get:54 http://archive.ubuntu.com/ubuntu bionic/main amd64 xserver-xorg-video-dummy amd64 1:0.3.8-1build1 [9,002 B]
# Get:55 http://archive.ubuntu.com/ubuntu bionic/universe amd64 xpra amd64 2.1.3+dfsg-1ubuntu1 [1,720 kB]
# Get:56 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpciaccess-dev amd64 0.14-1 [20.2 kB]
# Get:57 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 xserver-xorg-dev amd64 2:1.19.6-1ubuntu4.11 [198 kB]
# Get:58 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 xvfb amd64 2:1.19.6-1ubuntu4.11 [785 kB]
# Get:59 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libosmesa6 amd64 20.0.8-0ubuntu1~18.04.1 [2,641 kB]
# Get:60 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libosmesa6-dev amd64 20.0.8-0ubuntu1~18.04.1 [8,828 B]
# Fetched 15.0 MB in 3s (4,998 kB/s)
# Extracting templates from packages: 100%
# dpkg: xserver-xorg-core-hwe-18.04: dependency problems, but removing anyway as you requested:
#  xserver-xorg-video-nvidia-520 depends on xorg-video-abi-26 | xorg-video-abi-25 | xorg-video-abi-24 | xorg-video-abi-23 | xorg-video-abi-20 | xorg-video-abi-19 | xorg-video-abi-18 | xorg-video-abi-15 | xorg-video-abi-14 | xorg-video-abi-13 | xorg-video-abi-12 | xorg-video-abi-11 | xorg-video-abi-10 | xorg-video-abi-8 | xorg-video-abi-6.0; however:
#   Package xorg-video-abi-26 is not installed.
#   Package xorg-video-abi-25 is not installed.
#   Package xorg-video-abi-24 is not installed.
#   Package xserver-xorg-core-hwe-18.04 which provides xorg-video-abi-24 is to be removed.
#   Package xorg-video-abi-23 is not installed.
#   Package xorg-video-abi-20 is not installed.
#   Package xorg-video-abi-19 is not installed.
#   Package xorg-video-abi-18 is not installed.
#   Package xorg-video-abi-15 is not installed.
#   Package xorg-video-abi-14 is not installed.
#   Package xorg-video-abi-13 is not installed.
#   Package xorg-video-abi-12 is not installed.
#   Package xorg-video-abi-11 is not installed.
#   Package xorg-video-abi-10 is not installed.
#   Package xorg-video-abi-8 is not installed.
#   Package xorg-video-abi-6.0 is not installed.
#  xserver-xorg-video-nvidia-520 depends on xserver-xorg-core (>= 2:1.19.6-1ubuntu2~) | xserver-xorg-core-hwe-18.04; however:
#   Package xserver-xorg-core is not installed.
#   Package xserver-xorg-core-hwe-18.04 which provides xserver-xorg-core is to be removed.
#   Package xserver-xorg-core-hwe-18.04 is to be removed.
#  xserver-xorg-video-nvidia-520 depends on xorg-video-abi-26 | xorg-video-abi-25 | xorg-video-abi-24 | xorg-video-abi-23 | xorg-video-abi-20 | xorg-video-abi-19 | xorg-video-abi-18 | xorg-video-abi-15 | xorg-video-abi-14 | xorg-video-abi-13 | xorg-video-abi-12 | xorg-video-abi-11 | xorg-video-abi-10 | xorg-video-abi-8 | xorg-video-abi-6.0; however:
#   Package xorg-video-abi-26 is not installed.
#   Package xorg-video-abi-25 is not installed.
#   Package xorg-video-abi-24 is not installed.
#   Package xserver-xorg-core-hwe-18.04 which provides xorg-video-abi-24 is to be removed.
#   Package xorg-video-abi-23 is not installed.
#   Package xorg-video-abi-20 is not installed.
#   Package xorg-video-abi-19 is not installed.
#   Package xorg-video-abi-18 is not installed.
#   Package xorg-video-abi-15 is not installed.
#   Package xorg-video-abi-14 is not installed.
#   Package xorg-video-abi-13 is not installed.
#   Package xorg-video-abi-12 is not installed.
#   Package xorg-video-abi-11 is not installed.
#   Package xorg-video-abi-10 is not installed.
#   Package xorg-video-abi-8 is not installed.
#   Package xorg-video-abi-6.0 is not installed.
#  xserver-xorg-video-nvidia-520 depends on xserver-xorg-core (>= 2:1.19.6-1ubuntu2~) | xserver-xorg-core-hwe-18.04; however:
#   Package xserver-xorg-core is not installed.
#   Package xserver-xorg-core-hwe-18.04 which provides xserver-xorg-core is to be removed.
#   Package xserver-xorg-core-hwe-18.04 is to be removed.
#  xserver-xorg-video-nvidia-520 depends on xorg-video-abi-26 | xorg-video-abi-25 | xorg-video-abi-24 | xorg-video-abi-23 | xorg-video-abi-20 | xorg-video-abi-19 | xorg-video-abi-18 | xorg-video-abi-15 | xorg-video-abi-14 | xorg-video-abi-13 | xorg-video-abi-12 | xorg-video-abi-11 | xorg-video-abi-10 | xorg-video-abi-8 | xorg-video-abi-6.0; however:
#   Package xorg-video-abi-26 is not installed.
#   Package xorg-video-abi-25 is not installed.
#   Package xorg-video-abi-24 is not installed.
#   Package xserver-xorg-core-hwe-18.04 which provides xorg-video-abi-24 is to be removed.
#   Package xorg-video-abi-23 is not installed.
#   Package xorg-video-abi-20 is not installed.
#   Package xorg-video-abi-19 is not installed.
#   Package xorg-video-abi-18 is not installed.
#   Package xorg-video-abi-15 is not installed.
#   Package xorg-video-abi-14 is not installed.
#   Package xorg-video-abi-13 is not installed.
#   Package xorg-video-abi-12 is not installed.
#   Package xorg-video-abi-11 is not installed.
#   Package xorg-video-abi-10 is not installed.
#   Package xorg-video-abi-8 is not installed.
#   Package xorg-video-abi-6.0 is not installed.
#  xserver-xorg-video-nvidia-520 depends on xserver-xorg-core (>= 2:1.19.6-1ubuntu2~) | xserver-xorg-core-hwe-18.04; however:
#   Package xserver-xorg-core is not installed.
#   Package xserver-xorg-core-hwe-18.04 which provides xserver-xorg-core is to be removed.
#   Package xserver-xorg-core-hwe-18.04 is to be removed.
#
# (Reading database ... 123942 files and directories currently installed.)
# Removing xserver-xorg-core-hwe-18.04 (2:1.20.8-2ubuntu2.2~18.04.7) ...
# Selecting previously unselected package xserver-xorg-core.
# (Reading database ... 123903 files and directories currently installed.)
# Preparing to unpack .../00-xserver-xorg-core_2%3a1.19.6-1ubuntu4.11_amd64.deb ...
# Unpacking xserver-xorg-core (2:1.19.6-1ubuntu4.11) ...
# Selecting previously unselected package libfile-next-perl.
# Preparing to unpack .../01-libfile-next-perl_1.16-2_all.deb ...
# Unpacking libfile-next-perl (1.16-2) ...
# Selecting previously unselected package ack.
# Preparing to unpack .../02-ack_2.22-1_all.deb ...
# Unpacking ack (2.22-1) ...
# Selecting previously unselected package ack-grep.
# Preparing to unpack .../03-ack-grep_2.22-1_all.deb ...
# Unpacking ack-grep (2.22-1) ...
# Selecting previously unselected package libgl1-mesa-glx:amd64.
# Preparing to unpack .../04-libgl1-mesa-glx_20.0.8-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking libgl1-mesa-glx:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# Selecting previously unselected package freeglut3:amd64.
# Preparing to unpack .../05-freeglut3_2.8.1-3_amd64.deb ...
# Unpacking freeglut3:amd64 (2.8.1-3) ...
# Selecting previously unselected package libcapnp-0.6.1:amd64.
# Preparing to unpack .../06-libcapnp-0.6.1_0.6.1-1ubuntu1_amd64.deb ...
# Unpacking libcapnp-0.6.1:amd64 (0.6.1-1ubuntu1) ...
# Selecting previously unselected package libfontenc-dev:amd64.
# Preparing to unpack .../07-libfontenc-dev_1%3a1.1.3-1_amd64.deb ...
# Unpacking libfontenc-dev:amd64 (1:1.1.3-1) ...
# Selecting previously unselected package libglew2.0:amd64.
# Preparing to unpack .../08-libglew2.0_2.0.0-5_amd64.deb ...
# Unpacking libglew2.0:amd64 (2.0.0-5) ...
# Selecting previously unselected package libglew-dev:amd64.
# Preparing to unpack .../09-libglew-dev_2.0.0-5_amd64.deb ...
# Unpacking libglew-dev:amd64 (2.0.0-5) ...
# Selecting previously unselected package libglfw3:amd64.
# Preparing to unpack .../10-libglfw3_3.2.1-1_amd64.deb ...
# Unpacking libglfw3:amd64 (3.2.1-1) ...
# Selecting previously unselected package libglfw3-dev:amd64.
# Preparing to unpack .../11-libglfw3-dev_3.2.1-1_amd64.deb ...
# Unpacking libglfw3-dev:amd64 (3.2.1-1) ...
# Selecting previously unselected package libgtk2.0-common.
# Preparing to unpack .../12-libgtk2.0-common_2.24.32-1ubuntu1_all.deb ...
# Unpacking libgtk2.0-common (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../13-libgtk2.0-0_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libmircore1:amd64.
# Preparing to unpack .../14-libmircore1_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircore1:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmircommon7:amd64.
# Preparing to unpack .../15-libmircommon7_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircommon7:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libprotobuf-lite10:amd64.
# Preparing to unpack .../16-libprotobuf-lite10_3.0.0-9.1ubuntu1_amd64.deb ...
# Unpacking libprotobuf-lite10:amd64 (3.0.0-9.1ubuntu1) ...
# Selecting previously unselected package libmirprotobuf3:amd64.
# Preparing to unpack .../17-libmirprotobuf3_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmirprotobuf3:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmirclient9:amd64.
# Preparing to unpack .../18-libmirclient9_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmirclient9:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmircore-dev:amd64.
# Preparing to unpack .../19-libmircore-dev_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircore-dev:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libprotobuf-dev:amd64.
# Preparing to unpack .../20-libprotobuf-dev_3.0.0-9.1ubuntu1_amd64.deb ...
# Unpacking libprotobuf-dev:amd64 (3.0.0-9.1ubuntu1) ...
# Selecting previously unselected package libxkbcommon-dev:amd64.
# Preparing to unpack .../21-libxkbcommon-dev_0.8.2-1~ubuntu18.04.1_amd64.deb ...
# Unpacking libxkbcommon-dev:amd64 (0.8.2-1~ubuntu18.04.1) ...
# Selecting previously unselected package libmircommon-dev:amd64.
# Preparing to unpack .../22-libmircommon-dev_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircommon-dev:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmircookie2:amd64.
# Preparing to unpack .../23-libmircookie2_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircookie2:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmircookie-dev:amd64.
# Preparing to unpack .../24-libmircookie-dev_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircookie-dev:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmirclient-dev:amd64.
# Preparing to unpack .../25-libmirclient-dev_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmirclient-dev:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libpixman-1-dev:amd64.
# Preparing to unpack .../26-libpixman-1-dev_0.34.0-2_amd64.deb ...
# Unpacking libpixman-1-dev:amd64 (0.34.0-2) ...
# Selecting previously unselected package libxcursor-dev:amd64.
# Preparing to unpack .../27-libxcursor-dev_1%3a1.1.15-1_amd64.deb ...
# Unpacking libxcursor-dev:amd64 (1:1.1.15-1) ...
# Selecting previously unselected package x11proto-fonts-dev.
# Preparing to unpack .../28-x11proto-fonts-dev_2018.4-4_all.deb ...
# Unpacking x11proto-fonts-dev (2018.4-4) ...
# Selecting previously unselected package libxfont-dev.
# Preparing to unpack .../29-libxfont-dev_1%3a2.0.3-1_amd64.deb ...
# Unpacking libxfont-dev (1:2.0.3-1) ...
# Selecting previously unselected package x11proto-xinerama-dev.
# Preparing to unpack .../30-x11proto-xinerama-dev_2018.4-4_all.deb ...
# Unpacking x11proto-xinerama-dev (2018.4-4) ...
# Selecting previously unselected package libxinerama-dev:amd64.
# Preparing to unpack .../31-libxinerama-dev_2%3a1.1.3-1_amd64.deb ...
# Unpacking libxinerama-dev:amd64 (2:1.1.3-1) ...
# Selecting previously unselected package libxkbfile-dev:amd64.
# Preparing to unpack .../32-libxkbfile-dev_1%3a1.0.9-2_amd64.deb ...
# Unpacking libxkbfile-dev:amd64 (1:1.0.9-2) ...
# Selecting previously unselected package mir-client-platform-mesa-dev:amd64.
# Preparing to unpack .../33-mir-client-platform-mesa-dev_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking mir-client-platform-mesa-dev:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package patchelf.
# Preparing to unpack .../34-patchelf_0.9-1_amd64.deb ...
# Unpacking patchelf (0.9-1) ...
# Selecting previously unselected package python-cairo:amd64.
# Preparing to unpack .../35-python-cairo_1.16.2-1_amd64.deb ...
# Unpacking python-cairo:amd64 (1.16.2-1) ...
# Selecting previously unselected package python-gi.
# Preparing to unpack .../36-python-gi_3.26.1-2ubuntu1_amd64.deb ...
# Unpacking python-gi (3.26.1-2ubuntu1) ...
# Selecting previously unselected package python-gi-cairo.
# Preparing to unpack .../37-python-gi-cairo_3.26.1-2ubuntu1_amd64.deb ...
# Unpacking python-gi-cairo (3.26.1-2ubuntu1) ...
# Selecting previously unselected package python-gobject-2.
# Preparing to unpack .../38-python-gobject-2_2.28.6-12ubuntu3_amd64.deb ...
# Unpacking python-gobject-2 (2.28.6-12ubuntu3) ...
# Selecting previously unselected package python-gtk2.
# Preparing to unpack .../39-python-gtk2_2.24.0-5.1ubuntu2_amd64.deb ...
# Unpacking python-gtk2 (2.24.0-5.1ubuntu2) ...
# Selecting previously unselected package python-opengl.
# Preparing to unpack .../40-python-opengl_3.1.0+dfsg-1_all.deb ...
# Unpacking python-opengl (3.1.0+dfsg-1) ...
# Selecting previously unselected package python-rencode.
# Preparing to unpack .../41-python-rencode_1.0.5-1build2_amd64.deb ...
# Unpacking python-rencode (1.0.5-1build2) ...
# Selecting previously unselected package swig3.0.
# Preparing to unpack .../42-swig3.0_3.0.12-1_amd64.deb ...
# Unpacking swig3.0 (3.0.12-1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../43-swig_3.0.12-1_amd64.deb ...
# Unpacking swig (3.0.12-1) ...
# Selecting previously unselected package x11-xserver-utils.
# Preparing to unpack .../44-x11-xserver-utils_7.7+7build1_amd64.deb ...
# Unpacking x11-xserver-utils (7.7+7build1) ...
# Selecting previously unselected package x11proto-dri2-dev.
# Preparing to unpack .../45-x11proto-dri2-dev_2018.4-4_all.deb ...
# Unpacking x11proto-dri2-dev (2018.4-4) ...
# Selecting previously unselected package x11proto-gl-dev.
# Preparing to unpack .../46-x11proto-gl-dev_2018.4-4_all.deb ...
# Unpacking x11proto-gl-dev (2018.4-4) ...
# Selecting previously unselected package x11proto-input-dev.
# Preparing to unpack .../47-x11proto-input-dev_2018.4-4_all.deb ...
# Unpacking x11proto-input-dev (2018.4-4) ...
# Selecting previously unselected package x11proto-randr-dev.
# Preparing to unpack .../48-x11proto-randr-dev_2018.4-4_all.deb ...
# Unpacking x11proto-randr-dev (2018.4-4) ...
# Selecting previously unselected package x11proto-render-dev.
# Preparing to unpack .../49-x11proto-render-dev_2%3a2018.4-4_all.deb ...
# Unpacking x11proto-render-dev (2:2018.4-4) ...
# Selecting previously unselected package x11proto-resource-dev.
# Preparing to unpack .../50-x11proto-resource-dev_2018.4-4_all.deb ...
# Unpacking x11proto-resource-dev (2018.4-4) ...
# Selecting previously unselected package x11proto-xf86bigfont-dev.
# Preparing to unpack .../51-x11proto-xf86bigfont-dev_2018.4-4_all.deb ...
# Unpacking x11proto-xf86bigfont-dev (2018.4-4) ...
# Selecting previously unselected package xserver-xorg-input-void.
# Preparing to unpack .../52-xserver-xorg-input-void_1%3a1.4.1-1build3_amd64.deb ...
# Unpacking xserver-xorg-input-void (1:1.4.1-1build3) ...
# Selecting previously unselected package xserver-xorg-video-dummy.
# Preparing to unpack .../53-xserver-xorg-video-dummy_1%3a0.3.8-1build1_amd64.deb ...
# Unpacking xserver-xorg-video-dummy (1:0.3.8-1build1) ...
# Selecting previously unselected package xpra.
# Preparing to unpack .../54-xpra_2.1.3+dfsg-1ubuntu1_amd64.deb ...
# Unpacking xpra (2.1.3+dfsg-1ubuntu1) ...
# Selecting previously unselected package libpciaccess-dev:amd64.
# Preparing to unpack .../55-libpciaccess-dev_0.14-1_amd64.deb ...
# Unpacking libpciaccess-dev:amd64 (0.14-1) ...
# Selecting previously unselected package xserver-xorg-dev.
# Preparing to unpack .../56-xserver-xorg-dev_2%3a1.19.6-1ubuntu4.11_amd64.deb ...
# Unpacking xserver-xorg-dev (2:1.19.6-1ubuntu4.11) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../57-xvfb_2%3a1.19.6-1ubuntu4.11_amd64.deb ...
# Unpacking xvfb (2:1.19.6-1ubuntu4.11) ...
# Selecting previously unselected package libosmesa6:amd64.
# Preparing to unpack .../58-libosmesa6_20.0.8-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking libosmesa6:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# Selecting previously unselected package libosmesa6-dev:amd64.
# Preparing to unpack .../59-libosmesa6-dev_20.0.8-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking libosmesa6-dev:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# Setting up x11proto-fonts-dev (2018.4-4) ...
# Setting up python-rencode (1.0.5-1build2) ...
# Setting up x11proto-dri2-dev (2018.4-4) ...
# Setting up freeglut3:amd64 (2.8.1-3) ...
# Setting up libxcursor-dev:amd64 (1:1.1.15-1) ...
# Setting up patchelf (0.9-1) ...
# Setting up libgtk2.0-common (2.24.32-1ubuntu1) ...
# Setting up libxkbcommon-dev:amd64 (0.8.2-1~ubuntu18.04.1) ...
# Setting up python-opengl (3.1.0+dfsg-1) ...
# Setting up swig3.0 (3.0.12-1) ...
# Setting up libpciaccess-dev:amd64 (0.14-1) ...
# Setting up libmircore-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up libfile-next-perl (1.16-2) ...
# Setting up xvfb (2:1.19.6-1ubuntu4.11) ...
# Setting up libosmesa6:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# Setting up libglfw3:amd64 (3.2.1-1) ...
# Setting up ack (2.22-1) ...
# Setting up x11proto-xf86bigfont-dev (2018.4-4) ...
# Setting up libxkbfile-dev:amd64 (1:1.0.9-2) ...
# Setting up xserver-xorg-core (2:1.19.6-1ubuntu4.11) ...
# Setting up python-gobject-2 (2.28.6-12ubuntu3) ...
# Setting up libmircookie2:amd64 (0.31.1-0ubuntu1) ...
# Setting up python-gi (3.26.1-2ubuntu1) ...
# Setting up libfontenc-dev:amd64 (1:1.1.3-1) ...
# Setting up xserver-xorg-video-dummy (1:0.3.8-1build1) ...
# Setting up libgl1-mesa-glx:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# Setting up x11proto-xinerama-dev (2018.4-4) ...
# Setting up libpixman-1-dev:amd64 (0.34.0-2) ...
# Setting up x11proto-randr-dev (2018.4-4) ...
# Setting up libxinerama-dev:amd64 (2:1.1.3-1) ...
# Setting up xserver-xorg-input-void (1:1.4.1-1build3) ...
# Setting up x11proto-gl-dev (2018.4-4) ...
# Setting up libcapnp-0.6.1:amd64 (0.6.1-1ubuntu1) ...
# Setting up python-cairo:amd64 (1.16.2-1) ...
# Setting up libglew2.0:amd64 (2.0.0-5) ...
# Setting up x11-xserver-utils (7.7+7build1) ...
# Setting up x11proto-resource-dev (2018.4-4) ...
# Setting up x11proto-render-dev (2:2018.4-4) ...
# Setting up libmircore1:amd64 (0.31.1-0ubuntu1) ...
# Setting up libprotobuf-lite10:amd64 (3.0.0-9.1ubuntu1) ...
# Setting up libglew-dev:amd64 (2.0.0-5) ...
# Setting up x11proto-input-dev (2018.4-4) ...
# Setting up libglfw3-dev:amd64 (3.2.1-1) ...
# Setting up python-gi-cairo (3.26.1-2ubuntu1) ...
# Setting up libgtk2.0-0:amd64 (2.24.32-1ubuntu1) ...
# Setting up swig (3.0.12-1) ...
# Setting up ack-grep (2.22-1) ...
# Setting up libosmesa6-dev:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# Setting up libmirprotobuf3:amd64 (0.31.1-0ubuntu1) ...
# Setting up libprotobuf-dev:amd64 (3.0.0-9.1ubuntu1) ...
# Setting up python-gtk2 (2.24.0-5.1ubuntu2) ...
# Setting up libmircookie-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up libxfont-dev (1:2.0.3-1) ...
# Setting up libmircommon7:amd64 (0.31.1-0ubuntu1) ...
# Setting up xpra (2.1.3+dfsg-1ubuntu1) ...
# Created symlink /etc/systemd/system/multi-user.target.wants/xpra.service → /lib/systemd/system/xpra.service.
# Setting up libmirclient9:amd64 (0.31.1-0ubuntu1) ...
# Setting up libmircommon-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up libmirclient-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up mir-client-platform-mesa-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up xserver-xorg-dev (2:1.19.6-1ubuntu4.11) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.6) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for shared-mime-info (1.9-2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...

# %%
#@title clone homework repo

# %cd $SYM_PATH
# %cd hw2/
# %pip install -r requirements_colab.txt
# %pip install gym[box2d]==0.25.2
# %pip install -e .
# Out:
# /content/gdrive/My Drive/CS285 Project
# /content/gdrive/My Drive/CS285 Project/hw2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mujoco==2.2.0
#   Downloading mujoco-2.2.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 7.4 MB/s
# Requirement already satisfied: gym==0.25.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements_colab.txt (line 2)) (0.25.2)
# Collecting tensorboardX==2.5.1
#   Downloading tensorboardX-2.5.1-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 64.0 MB/s
# Collecting moviepy==1.0.3
#   Downloading moviepy-1.0.3.tar.gz (388 kB)
#      |████████████████████████████████| 388 kB 62.3 MB/s
# Collecting pyvirtualdisplay==3.0
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: torch==1.12.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements_colab.txt (line 6)) (1.12.1+cu113)
# Requirement already satisfied: opencv-python==4.6.0.66 in /usr/local/lib/python3.7/dist-packages (from -r requirements_colab.txt (line 7)) (4.6.0.66)
# Collecting swig==4.0.2
#   Downloading swig-4.0.2-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.7 MB)
#      |████████████████████████████████| 3.7 MB 47.2 MB/s
# Collecting box2d-py==2.3.8
#   Downloading box2d_py-2.3.8-cp37-cp37m-manylinux1_x86_64.whl (448 kB)
#      |████████████████████████████████| 448 kB 69.5 MB/s
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from mujoco==2.2.0->-r requirements_colab.txt (line 1)) (1.3.0)
# Collecting glfw
#   Downloading glfw-2.5.5-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38-none-manylinux2014_x86_64.whl (207 kB)
#      |████████████████████████████████| 207 kB 76.2 MB/s
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.7/dist-packages (from mujoco==2.2.0->-r requirements_colab.txt (line 1)) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from mujoco==2.2.0->-r requirements_colab.txt (line 1)) (1.21.6)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym==0.25.2->-r requirements_colab.txt (line 2)) (1.5.0)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.7/dist-packages (from gym==0.25.2->-r requirements_colab.txt (line 2)) (0.0.8)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /usr/local/lib/python3.7/dist-packages (from gym==0.25.2->-r requirements_colab.txt (line 2)) (4.13.0)
# Requirement already satisfied: protobuf<=3.20.1,>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorboardX==2.5.1->-r requirements_colab.txt (line 3)) (3.17.3)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.7/dist-packages (from moviepy==1.0.3->-r requirements_colab.txt (line 4)) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.7/dist-packages (from moviepy==1.0.3->-r requirements_colab.txt (line 4)) (4.64.1)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.7/dist-packages (from moviepy==1.0.3->-r requirements_colab.txt (line 4)) (2.23.0)
# Collecting proglog<=1.0.0
#   Downloading proglog-0.1.10-py3-none-any.whl (6.1 kB)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.7/dist-packages (from moviepy==1.0.3->-r requirements_colab.txt (line 4)) (2.9.0)
# Collecting imageio_ffmpeg>=0.2.0
#   Downloading imageio_ffmpeg-0.4.7-py3-none-manylinux2010_x86_64.whl (26.9 MB)
#      |████████████████████████████████| 26.9 MB 1.5 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.12.1->-r requirements_colab.txt (line 6)) (4.1.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from imageio<3.0,>=2.5->moviepy==1.0.3->-r requirements_colab.txt (line 4)) (7.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.8.0->gym==0.25.2->-r requirements_colab.txt (line 2)) (3.9.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf<=3.20.1,>=3.8.0->tensorboardX==2.5.1->-r requirements_colab.txt (line 3)) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.8.1->moviepy==1.0.3->-r requirements_colab.txt (line 4)) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.8.1->moviepy==1.0.3->-r requirements_colab.txt (line 4)) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.8.1->moviepy==1.0.3->-r requirements_colab.txt (line 4)) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.8.1->moviepy==1.0.3->-r requirements_colab.txt (line 4)) (1.24.3)
# Building wheels for collected packages: moviepy
#   Building wheel for moviepy (setup.py) ... done
#   Created wheel for moviepy: filename=moviepy-1.0.3-py3-none-any.whl size=110743 sha256=729ae717c49a04e822f4c99345e3cb317873b277fd10f28aa6a75271de352287
#   Stored in directory: /root/.cache/pip/wheels/56/dc/2b/9cd600d483c04af3353d66623056fc03faed76b7518faae4df
# Successfully built moviepy
# Installing collected packages: proglog, imageio-ffmpeg, glfw, tensorboardX, swig, pyvirtualdisplay, mujoco, moviepy, box2d-py
#   Attempting uninstall: moviepy
#     Found existing installation: moviepy 0.2.3.5
#     Uninstalling moviepy-0.2.3.5:
#       Successfully uninstalled moviepy-0.2.3.5
# Successfully installed box2d-py-2.3.8 glfw-2.5.5 imageio-ffmpeg-0.4.7 moviepy-1.0.3 mujoco-2.2.0 proglog-0.1.10 pyvirtualdisplay-3.0 swig-4.0.2 tensorboardX-2.5.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gym[box2d]==0.25.2 in /usr/local/lib/python3.7/dist-packages (0.25.2)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /usr/local/lib/python3.7/dist-packages (from gym[box2d]==0.25.2) (4.13.0)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.7/dist-packages (from gym[box2d]==0.25.2) (0.0.8)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.7/dist-packages (from gym[box2d]==0.25.2) (1.21.6)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym[box2d]==0.25.2) (1.5.0)
# Collecting pygame==2.1.0
#   Downloading pygame-2.1.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#      |████████████████████████████████| 18.3 MB 7.5 MB/s
# Collecting box2d-py==2.3.5
#   Downloading box2d_py-2.3.5-cp37-cp37m-manylinux1_x86_64.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 39.3 MB/s
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.7/dist-packages (from gym[box2d]==0.25.2) (4.0.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.8.0->gym[box2d]==0.25.2) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.8.0->gym[box2d]==0.25.2) (3.9.0)
# Installing collected packages: pygame, box2d-py
#   Attempting uninstall: box2d-py
#     Found existing installation: box2d-py 2.3.8
#     Uninstalling box2d-py-2.3.8:
#       Successfully uninstalled box2d-py-2.3.8
# Successfully installed box2d-py-2.3.5 pygame-2.1.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/gdrive/My%20Drive/CS285%20Project/hw2
# Installing collected packages: cs285
#   Running setup.py develop for cs285
# Successfully installed cs285-0.1.0

# %%
#@title set up virtual display

from pyvirtualdisplay import Display

display = Display(visible=0, size=(1400, 900))
display.start()

# %%
#@title test virtual display

#@markdown If you see a video of a four-legged ant fumbling about, setup is complete!

import gym
from cs285.infrastructure.colab_utils import (
    wrap_env,
    show_video
)

env = wrap_env(gym.make("Ant-v4", render_mode='rgb_array'))

observation = env.reset()
for i in range(100):
    env.render()
    obs, rew, term, _ = env.step(env.action_space.sample() ) 
    if term:
      break;
            
env.close()
print('Loading video...')
show_video()
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/core.py:318: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   "Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future."
# /usr/local/lib/python3.7/dist-packages/gym/wrappers/step_api_compatibility.py:40: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   "Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future."

# %% [markdown]
# ## Editing Code
#
# To edit code, click the folder icon on the left menu. Navigate to the corresponding file (`cs285_f2022/...`). Double click a file to open an editor. There is a timeout of about ~12 hours with Colab while it is active (and less if you close your browser window). We sync your edits to Google Drive so that you won't lose your work in the event of an instance timeout, but you will need to re-mount your Google Drive and re-install packages with every new instance.

# %% [markdown]
# ## Run Policy Gradients

# %%
#@title imports

import os
import time

from cs285.infrastructure.rl_trainer import RL_Trainer
from cs285.agents.pg_agent import PGAgent

# %load_ext autoreload
# %autoreload 2

# %%
#@title runtime arguments

class Args:

  def __getitem__(self, key):
    return getattr(self, key)

  def __setitem__(self, key, val):
    setattr(self, key, val)

  def __contains__(self, key):
    return hasattr(self, key)

  env_name = 'CartPole-v0' #@param
  exp_name = 'q1_sb_rtg_na' #@param

  #@markdown main parameters of interest
  n_iter = 100 #@param {type: "integer"}

  ## PDF will tell you how to set ep_len
  ## and discount for each environment
  ep_len = 200 #@param {type: "integer"}
  discount = 0.95 #@param {type: "number"}

  reward_to_go = True #@param {type: "boolean"}
  nn_baseline = False #@param {type: "boolean"}
  gae_lambda = None #@param {type: "float"}
  dont_standardize_advantages = False #@param {type: "boolean"}

  #@markdown batches and steps
  batch_size = 1000 #@param {type: "integer"}
  eval_batch_size = 400 #@param {type: "integer"}

  num_agent_train_steps_per_iter = 1 #@param {type: "integer"}
  learning_rate =  5e-3 #@param {type: "number"}

  #@markdown MLP parameters
  n_layers = 2 #@param {type: "integer"}
  size = 64 #@param {type: "integer"}

  #@markdown system
  save_params = False #@param {type: "boolean"}
  no_gpu = False #@param {type: "boolean"}
  which_gpu = 0 #@param {type: "integer"}
  seed = 1 #@param {type: "integer"}
    
  action_noise_std = 0 #@param {type: "float"}

  #@markdown logging
  ## default is to not log video so
  ## that logs are small enough to be
  ## uploaded to gradscope
  video_log_freq =  -1#@param {type: "integer"}
  scalar_log_freq =  1#@param {type: "integer"}


args = Args()

## ensure compatibility with hw1 code
args['train_batch_size'] = args['batch_size']

if args['video_log_freq'] > 0:
  import warnings
  warnings.warn(
      '''\nLogging videos will make eventfiles too'''
      '''\nlarge for the autograder. Set video_log_freq = -1'''
      '''\nfor the runs you intend to submit.''')

# %%
#@title create directory for logging

data_path = '/content/gdrive/My\ Drive/CS285\ Project/data/'
data_path = data_path.replace('\\', '')

if not (os.path.exists(data_path)):
    os.makedirs(data_path)

logdir = args.exp_name + '_' + args.env_name + '_' + time.strftime("%d-%m-%Y_%H-%M-%S")
logdir = os.path.join(data_path, logdir)
args['logdir'] = logdir
if not(os.path.exists(logdir)):
    os.makedirs(logdir)

# %%
## define policy gradient trainer

class PG_Trainer(object):

    def __init__(self, params):

        #####################
        ## SET AGENT PARAMS
        #####################

        computation_graph_args = {
            'n_layers': params['n_layers'],
            'size': params['size'],
            'learning_rate': params['learning_rate'],
            }

        estimate_advantage_args = {
            'gamma': params['discount'],
            'standardize_advantages': not(params['dont_standardize_advantages']),
            'reward_to_go': params['reward_to_go'],
            'nn_baseline': params['nn_baseline'],
            'gae_lambda': params['gae_lambda'],
        }

        train_args = {
            'num_agent_train_steps_per_iter': params['num_agent_train_steps_per_iter'],
        }

        agent_params = {**computation_graph_args, **estimate_advantage_args, **train_args}

        self.params = params
        self.params['agent_class'] = PGAgent
        self.params['agent_params'] = agent_params
        self.params['batch_size_initial'] = self.params['batch_size']

        ################
        ## RL TRAINER
        ################

        self.rl_trainer = RL_Trainer(self.params)

    def run_training_loop(self):

        self.rl_trainer.run_training_loop(
            self.params['n_iter'],
            collect_policy = self.rl_trainer.agent.actor,
            eval_policy = self.rl_trainer.agent.actor,
            )

# %%
## run training

print(args.logdir)
trainer = PG_Trainer(args)
trainer.run_training_loop()

# %%
#@markdown You can visualize your runs with tensorboard from within the notebook

## requires tensorflow==2.3.0
# %load_ext tensorboard
# %tensorboard --logdir /content/cs285_f2022/homework_fall2022/hw2/data
